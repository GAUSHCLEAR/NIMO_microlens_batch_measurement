# %%
import matplotlib.pyplot as plt
import os
from data_processing import *
from report_processing import *
import markdown
import os 

os.environ['OMP_NUM_THREADS'] = '1'

# %%
filename="one\RnDLot_slot_001_1_Sphere_PowerMap(1).csv"
data = read_data(filename)
binary_image = detect_edge(data,threshold=2)
microlenses, microlens_only_image = label_microlens(binary_image, min_area=1*1, max_area=40*40)

# %%
plt.imshow(binary_image, cmap='gray')
plt.show()
